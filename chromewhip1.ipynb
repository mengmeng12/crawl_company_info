# %%
import asyncio
import logging

from chromewhip import Chrome
from chromewhip.protocol import browser, page, dom
import lxml.html
import time
import datetime
import numpy as np
import pandas as pd
import time
from tqdm import tqdm_notebook as tqdm
from bs4 import BeautifulSoup
import re
import warnings
warnings.filterwarnings('ignore')

# %%
def convert_string_to_money(string):
    if string[-1] =='M':
        return float(string[:-1])*10e6
    elif string[-1]=='B':
        return float(string[:-1])*10e9
    else:
        print ('Do not know how to convert ',string)

# %%
# see logging from chromewhip
logging.basicConfig(level=logging.WARN)

HOST = '127.0.0.1'
PORT = 9222

loop = asyncio.get_event_loop()
c = Chrome(host=HOST, port=PORT)

# %%
loop.run_until_complete(c.connect())

# %%
def sync_cmd(*args, **kwargs):
    return loop.run_until_complete(tab.send_command(*args, **kwargs))

# %%
name='cancergenetics'
tab = c.tabs[0]
tab = loop.run_until_complete(c.create_tab())
loop.run_until_complete(tab.enable_page_events())
result = sync_cmd(page.Page.navigate(url='https://www.owler.com/company/'+name), 
                  await_on_event_type=page.FrameStoppedLoadingEvent)
result = sync_cmd(dom.DOM.getDocument())
result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
page_source = result['ack']['result']['outerHTML']
#soup = BeautifulSoup(page_source, 'html.parser')

tree = lxml.html.fromstring(page_source)
loop.run_until_complete(c.close_tab(tab))

# %%
xpath_revenue = '//*[@id="__next"]/div/div/div[1]/div/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[2]/h2'
revenue = tree.xpath(xpath_revenue)[0].text
# Out:
# '$20M'

# %%
for m in range(100):
    name=test.iloc[np.where(test.HHI>0)].index[m]
    tab = c.tabs[0]
    tab = loop.run_until_complete(c.create_tab())
    loop.run_until_complete(tab.enable_page_events())
    result = sync_cmd(page.Page.navigate(url='https://www.owler.com/company/'+name), 
                      await_on_event_type=page.FrameStoppedLoadingEvent)
    result = sync_cmd(dom.DOM.getDocument())
    result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
    page_source = result['ack']['result']['outerHTML']
    #soup = BeautifulSoup(page_source, 'html.parser')

    tree = lxml.html.fromstring(page_source)
    loop.run_until_complete(c.close_tab(tab))

    soup = BeautifulSoup(page_source, 'html.parser')
    tmp_revenue_list = soup.find_all('div', attrs={'class': 'table-col revenue'})[1:]
    competitors_revenue = []
    for x in tmp_revenue_list:
        tmpvalue = re.findall(".*>(.*)<.*",str(x))[0]
        if len(tmpvalue)!=0:
            competitors_revenue.append(tmpvalue[1:])
    competitors_revenue_float=[]
    for i in competitors_revenue: 
        if i[:6] ==' &lt; ':
            competitors_revenue_float.append(convert_string_to_money(i[6:]))
        else:
            competitors_revenue_float.append(convert_string_to_money(i))
    print (name)
    display(np.array(competitors_revenue_float[1:])/10e6 ==test.iloc[np.where(test.HHI>0)].iloc[m,10:10+len(competitors_revenue_float[1:])]/10e6)
    loop.run_until_complete(c.close_tab(tab))
# Out:
# cancergenetics
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: cancergenetics, dtype: bool
# topgifter
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# Name: topgifter, dtype: bool
# pica9
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: pica9, dtype: bool
# actionx
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4    False
# competitors revenue 5    False
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# Name: actionx, dtype: bool
# forgerock
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: forgerock, dtype: bool
# nakivo
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: nakivo, dtype: bool
# cytogelpharma
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# Name: cytogelpharma, dtype: bool
# outboundengine
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: outboundengine, dtype: bool
# datatorrent
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: datatorrent, dtype: bool
# clicdata
# competitors revenue 1      True
# competitors revenue 2      True
# competitors revenue 3      True
# competitors revenue 4      True
# competitors revenue 5      True
# competitors revenue 6      True
# competitors revenue 7      True
# competitors revenue 8     False
# competitors revenue 9     False
# competitors revenue 10     True
# Name: clicdata, dtype: bool
# celsion
# competitors revenue 1      True
# competitors revenue 2      True
# competitors revenue 3     False
# competitors revenue 4      True
# competitors revenue 5      True
# competitors revenue 6      True
# competitors revenue 7      True
# competitors revenue 8      True
# competitors revenue 9      True
# competitors revenue 10     True
# Name: celsion, dtype: bool
# worthit
# competitors revenue 1      True
# competitors revenue 2      True
# competitors revenue 3      True
# competitors revenue 4      True
# competitors revenue 5      True
# competitors revenue 6      True
# competitors revenue 7      True
# competitors revenue 8      True
# competitors revenue 9     False
# competitors revenue 10    False
# Name: worthit, dtype: bool
# nexb
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: nexb, dtype: bool
# qumulo
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: qumulo, dtype: bool
# soundbetter
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: soundbetter, dtype: bool
# fitstar
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: fitstar, dtype: bool
# gliffy
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: gliffy, dtype: bool
# flowserve
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: flowserve, dtype: bool
# codehs
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: codehs, dtype: bool
# snapshots
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: snapshots, dtype: bool
# brookstone
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: brookstone, dtype: bool
# simplyinsured
# competitors revenue 1      True
# competitors revenue 2      True
# competitors revenue 3      True
# competitors revenue 4      True
# competitors revenue 5      True
# competitors revenue 6     False
# competitors revenue 7      True
# competitors revenue 8      True
# competitors revenue 9      True
# competitors revenue 10     True
# Name: simplyinsured, dtype: bool
# emergefinancialwellness
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: emergefinancialwellness, dtype: bool
# yogatrail
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: yogatrail, dtype: bool
# cureeo
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: cureeo, dtype: bool
# owncloud
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: owncloud, dtype: bool
# pfsweb
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: pfsweb, dtype: bool
# hapyak
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: hapyak, dtype: bool
# mark43
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: mark43, dtype: bool
# infocheckpoint
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: infocheckpoint, dtype: bool
# rijuven
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: rijuven, dtype: bool
# brushfireinteractive
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: brushfireinteractive, dtype: bool
# seekretreat
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# Name: seekretreat, dtype: bool
# absolutdata
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: absolutdata, dtype: bool
# aayuja
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: aayuja, dtype: bool
# poppin
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: poppin, dtype: bool
# adbrain
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# Name: adbrain, dtype: bool
# deepforestmedia
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: deepforestmedia, dtype: bool
# zergnet
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: zergnet, dtype: bool
# crowdsupply
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: crowdsupply, dtype: bool
# ultralinqhealthcaresolutions
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: ultralinqhealthcaresolutions, dtype: bool
# ovascience
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: ovascience, dtype: bool
# everstring
# competitors revenue 1      True
# competitors revenue 2     False
# competitors revenue 3     False
# competitors revenue 4     False
# competitors revenue 5     False
# competitors revenue 6     False
# competitors revenue 7     False
# competitors revenue 8     False
# competitors revenue 9     False
# competitors revenue 10     True
# Name: everstring, dtype: bool
# ebuybit
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# Name: ebuybit, dtype: bool
# appcard
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: appcard, dtype: bool
# lumate
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: lumate, dtype: bool
# jibo
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: jibo, dtype: bool
# genapsys
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: genapsys, dtype: bool
# proxtome
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: proxtome, dtype: bool
# mobilesystem7
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: mobilesystem7, dtype: bool
# nexamp
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: nexamp, dtype: bool
# awesomenesstv
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: awesomenesstv, dtype: bool
# zeuss
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: zeuss, dtype: bool
# propertycapsule
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# Name: propertycapsule, dtype: bool
# finalsite
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: finalsite, dtype: bool
# zubie
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: zubie, dtype: bool
# truelens
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: truelens, dtype: bool
# keiretsuforum
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: keiretsuforum, dtype: bool
# cloudtags
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: cloudtags, dtype: bool
# gryphonnetworks
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: gryphonnetworks, dtype: bool
# clickquotesave
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: clickquotesave, dtype: bool
# keyme
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# Name: keyme, dtype: bool
# catapultdesign
# competitors revenue 1      True
# competitors revenue 2      True
# competitors revenue 3      True
# competitors revenue 4      True
# competitors revenue 5      True
# competitors revenue 6      True
# competitors revenue 7      True
# competitors revenue 8      True
# competitors revenue 9      True
# competitors revenue 10    False
# Name: catapultdesign, dtype: bool
# cadcrowd
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: cadcrowd, dtype: bool
# sumzero
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: sumzero, dtype: bool
# kemptechnologies
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: kemptechnologies, dtype: bool
# exablox
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: exablox, dtype: bool
# profitbricks
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: profitbricks, dtype: bool
# tvaxbiomedical
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: tvaxbiomedical, dtype: bool
# videoblocks
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: videoblocks, dtype: bool
# expertta
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: expertta, dtype: bool
# intellibatt
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: intellibatt, dtype: bool
# tutoruniverse
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: tutoruniverse, dtype: bool
# sherly
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# Name: sherly, dtype: bool
# solexel
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: solexel, dtype: bool
# mapbox
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: mapbox, dtype: bool
# logikcull
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: logikcull, dtype: bool
# cyphyworks
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: cyphyworks, dtype: bool
# sandhillangels
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: sandhillangels, dtype: bool
# creativelive
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: creativelive, dtype: bool
# zuli
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: zuli, dtype: bool
# scruddle
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# Name: scruddle, dtype: bool
# clearstorydata
# competitors revenue 1    False
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5    False
# competitors revenue 6    False
# competitors revenue 7    False
# competitors revenue 8    False
# competitors revenue 9    False
# Name: clearstorydata, dtype: bool
# canary
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: canary, dtype: bool
# fivetran
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: fivetran, dtype: bool
# opendorse
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: opendorse, dtype: bool
# dropifi
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# Name: dropifi, dtype: bool
# kihon
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: kihon, dtype: bool
# spaceview
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: spaceview, dtype: bool
# visitdays
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# Name: visitdays, dtype: bool
# tinybop
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: tinybop, dtype: bool
# chaikinanalytics
# competitors revenue 1    True
# competitors revenue 2    True
# competitors revenue 3    True
# competitors revenue 4    True
# competitors revenue 5    True
# competitors revenue 6    True
# competitors revenue 7    True
# competitors revenue 8    True
# competitors revenue 9    True
# Name: chaikinanalytics, dtype: bool
# theaudience
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: theaudience, dtype: bool
# dotloop
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: dotloop, dtype: bool
# kaybus
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: kaybus, dtype: bool
# backerkit
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: backerkit, dtype: bool
# mightyhive
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: mightyhive, dtype: bool
# bmobilized
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: bmobilized, dtype: bool
# gethuman
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: gethuman, dtype: bool
# skyonic
# competitors revenue 1     True
# competitors revenue 2     True
# competitors revenue 3     True
# competitors revenue 4     True
# competitors revenue 5     True
# competitors revenue 6     True
# competitors revenue 7     True
# competitors revenue 8     True
# competitors revenue 9     True
# competitors revenue 10    True
# Name: skyonic, dtype: bool

# %%
loop.run_until_complete(c.close_tab(tab))

# %%
test = pd.read_csv('tmp_company_info_for_owler_v2.csv',index_col=0)
test.iloc[np.where(test.HHI>0)].iloc[:,10:]/10e6
# Out:
#                          competitors revenue 1  competitors revenue 2  \
# Company.name
# cancergenetics                             3.8                    1.0
# topgifter                                  3.3                    3.6
# pica9                                     31.1                   70.3
# actionx                                  300.0                 2300.0
# forgerock                                 66.3                   33.5
# nakivo                                   999.2                   11.4
# cytogelpharma                              4.4                    3.0
# outboundengine                            27.0                  150.0
# datatorrent                                8.5                    2.4
# clicdata                                  34.0                  113.2
# celsion                                   63.8                   20.0
# worthit                                    3.0                    2.3
# nexb                                      37.5                    8.0
# qumulo                                    30.6                    3.0
# soundbetter                                5.0                    3.0
# fitstar                                    3.0                    3.0
# gliffy                                     3.5                   21.2
# flowserve                                123.7                 1500.0
# codehs                                     6.0                    3.0
# snapshots                                 12.0                   40.0
# brookstone                                10.0                  305.0
# simplyinsured                              3.8                    2.0
# emergefinancialwellness                    1.0                  109.2
# yogatrail                                  6.0                    3.5
# cureeo                                    10.0                   29.9
# owncloud                                   8.0                   16.5
# pfsweb                                    15.7                40100.0
# hapyak                                     1.0                    8.0
# mark43                                    11.3                    3.0
# infocheckpoint                             5.0                   84.4
# ...                                        ...                    ...
# autolotto                                  2.5                    4.5
# icecreamlabs                              11.0                    3.1
# tenantturner                              36.5                  177.6
# monkey                                     5.8                   99.0
# logfuze                                   19.5                    4.9
# yuggler                                    4.5                    1.1
# rpmarketplace                              4.4                   30.0
# sayist                                     7.5                   75.0
# casamatic                                  3.5                   24.5
# atomized                                  12.9                   70.0
# planday                                    5.2                    5.5
# writelab                                   1.0                  127.7
# veryapt                                   24.5                   55.0
# zoomph                                    15.3                   38.0
# bbgventures                               12.4                    7.7
# doggybnb                                  38.2                   12.3
# sqoop                                      3.1                    4.4
# callr                                     95.0                   10.0
# wazala                                     3.0                   12.1
# hyperscience                               3.0                    1.0
# wevorce                                    8.2                    8.0
# revfluence                                14.0                    7.0
# sourcegraph                                8.0                   43.3
# moneylion                                165.7                   17.0
# graybug                                    2.0                   10.0
# mongoosemetrics                           11.0                   20.7
# nventi                                     3.8                   18.8
# colonialbankfsb                            5.0                   21.0
# paracosm                                   3.0                    4.0
# extremeplasticsplus                       20.0                    5.0
#
#                          competitors revenue 3  competitors revenue 4  \
# Company.name
# cancergenetics                           377.0                    3.7
# topgifter                                 37.6                   25.7
# pica9                                     35.0                   10.0
# actionx                                  234.2                   12.0
# forgerock                                 11.0                   20.0
# nakivo                                    94.1                  440.6
# cytogelpharma                            694.1                   17.8
# outboundengine                            65.9                  109.7
# datatorrent                                4.5                    2.0
# clicdata                                1200.0                   10.0
# celsion                                  132.2                   47.7
# worthit                                   30.4                   12.5
# nexb                                       9.7                    3.6
# qumulo                                    29.3                   12.0
# soundbetter                                1.0                   27.6
# fitstar                                    5.0                    3.5
# gliffy                                    41.5                    1.0
# flowserve                               3200.0                    7.1
# codehs                                     4.0                    1.0
# snapshots                                 65.0                   24.7
# brookstone                               180.0                  137.1
# simplyinsured                              6.0                   13.3
# emergefinancialwellness                   70.0                    6.4
# yogatrail                                 26.4                    1.0
# cureeo                                     1.7                    3.4
# owncloud                                  80.0                   15.0
# pfsweb                                    33.2                    4.8
# hapyak                                    12.0                    2.0
# mark43                                    10.0                  935.3
# infocheckpoint                            18.0                    6.1
# ...                                        ...                    ...
# autolotto                                  2.5                    8.0
# icecreamlabs                              30.0                    3.9
# tenantturner                              73.3                   37.5
# monkey                                     4.1                  950.0
# logfuze                                    5.5                    9.8
# yuggler                                    1.0                    2.0
# rpmarketplace                              3.8                  100.0
# sayist                                    38.6                   50.0
# casamatic                                277.5                    4.0
# atomized                                   6.2                   12.5
# planday                                    7.8                    2.9
# writelab                                   7.8                  694.5
# veryapt                                  277.5                    1.0
# zoomph                                     3.9                    1.0
# bbgventures                               11.3                   10.3
# doggybnb                                   1.0                   55.1
# sqoop                                      2.8                   44.9
# callr                                     25.0                  493.1
# wazala                                    33.8                    4.4
# hyperscience                               5.9                   32.8
# wevorce                                   10.0                    3.0
# revfluence                                 6.2                    3.8
# sourcegraph                               11.0                   44.2
# moneylion                                 30.5                    5.0
# graybug                                    7.5                    6.7
# mongoosemetrics                           13.1                   15.3
# nventi                                     4.4                    5.3
# colonialbankfsb                            1.6                    4.3
# paracosm                                   3.0                    2.0
# extremeplasticsplus                        9.0                    0.0
#
#                          competitors revenue 5  competitors revenue 6  \
# Company.name
# cancergenetics                             1.0                   28.2
# topgifter                                 11.1                    1.2
# pica9                                      5.1                    1.1
# actionx                                    1.4                  601.0
# forgerock                                 47.0                   74.5
# nakivo                                   181.1                  194.1
# cytogelpharma                              0.0                    0.0
# outboundengine                            12.0                   11.0
# datatorrent                               10.9                   20.0
# clicdata                                   3.9                    3.0
# celsion                                    5.0                   20.0
# worthit                                   17.7                   11.1
# nexb                                       9.5                   11.0
# qumulo                                    50.0                    1.0
# soundbetter                                3.5                    2.4
# fitstar                                    3.0                    3.0
# gliffy                                     2.9                    5.9
# flowserve                                 10.0                   13.5
# codehs                                     5.0                   48.3
# snapshots                                 50.0                   27.6
# brookstone                                 9.9                   18.5
# simplyinsured                              4.2                  151.3
# emergefinancialwellness                 1500.0                    9.6
# yogatrail                                 10.0                    5.0
# cureeo                                     7.5                    6.6
# owncloud                                   7.4                    2.7
# pfsweb                                  4000.0                79600.0
# hapyak                                     3.3                    1.4
# mark43                                    25.0                    2.0
# infocheckpoint                            16.1                  114.7
# ...                                        ...                    ...
# autolotto                                  0.0                    0.0
# icecreamlabs                               7.0                    2.0
# tenantturner                               5.0                  830.2
# monkey                                     1.0                  782.5
# logfuze                                   72.4                 1600.0
# yuggler                                    5.0                    3.0
# rpmarketplace                             40.0                   15.0
# sayist                                     5.0                   10.0
# casamatic                                 55.0                    4.1
# atomized                                   2.0                  203.5
# planday                                    1.0                    1.0
# writelab                                   3.0                    4.8
# veryapt                                    3.8                    4.0
# zoomph                                    27.0                    5.8
# bbgventures                                1.6                    6.3
# doggybnb                                   1.6                   39.7
# sqoop                                     12.5                    5.0
# callr                                     13.1                    2.0
# wazala                                    27.2                   24.9
# hyperscience                               9.4                    7.0
# wevorce                                   21.3                    7.0
# revfluence                                 2.0                    3.0
# sourcegraph                               20.0                   55.6
# moneylion                                  3.8                    8.0
# graybug                                    1.0                    3.0
# mongoosemetrics                          103.3                    3.1
# nventi                                     5.6                   39.7
# colonialbankfsb                           13.4                   13.2
# paracosm                                  17.7                   41.0
# extremeplasticsplus                        0.0                    0.0
#
#                          competitors revenue 7  competitors revenue 8  \
# Company.name
# cancergenetics                             3.5                    6.5
# topgifter                                  0.0                    0.0
# pica9                                      4.4                   29.4
# actionx                                    4.4                   24.9
# forgerock                                  1.0                    8.0
# nakivo                                    35.3                   27.6
# cytogelpharma                              0.0                    0.0
# outboundengine                            22.2                   31.6
# datatorrent                                1.0                   21.0
# clicdata                                  13.5                  678.1
# celsion                                    3.2                  106.0
# worthit                                   32.8                   18.9
# nexb                                      17.6                    6.0
# qumulo                                  9200.0                    5.0
# soundbetter                                3.8                   10.5
# fitstar                                    3.0                   45.0
# gliffy                                     4.1                    7.1
# flowserve                              96300.0                  181.7
# codehs                                   166.8                    8.0
# snapshots                                558.1                    6.0
# brookstone                               150.0                   60.0
# simplyinsured                             80.0                    8.0
# emergefinancialwellness                  694.8                    7.5
# yogatrail                                  1.0                   24.1
# cureeo                                     5.3                    9.5
# owncloud                                  12.0                   18.0
# pfsweb                                 58500.0                38800.0
# hapyak                                    33.8                    2.4
# mark43                                     5.1                   50.0
# infocheckpoint                            87.3                   12.0
# ...                                        ...                    ...
# autolotto                                  0.0                    0.0
# icecreamlabs                               1.0                   31.6
# tenantturner                             662.0                    3.4
# monkey                                    17.0                    3.5
# logfuze                                    5.0                    7.5
# yuggler                                   45.0                    1.7
# rpmarketplace                              4.1                    3.8
# sayist                                     9.9                    3.2
# casamatic                                 10.0                    5.0
# atomized                                   6.0                    5.0
# planday                                    2.4                   62.8
# writelab                                   3.9                   15.0
# veryapt                                    4.9                    1.5
# zoomph                                    65.9                    2.0
# bbgventures                                3.6                   15.7
# doggybnb                                  50.1                    1.0
# sqoop                                     16.0                   12.4
# callr                                     66.3                   20.7
# wazala                                    10.6                    5.0
# hyperscience                               3.0                  229.1
# wevorce                                   30.0                 2800.0
# revfluence                                 2.0                    6.0
# sourcegraph                             3200.0                 4000.0
# moneylion                                 10.0                    5.0
# graybug                                    5.0                    1.4
# mongoosemetrics                           10.0                   15.8
# nventi                                    27.5                    0.0
# colonialbankfsb                           10.2                   31.8
# paracosm                                   1.0                    4.4
# extremeplasticsplus                        0.0                    0.0
#
#                          competitors revenue 9  competitors revenue 10
# Company.name
# cancergenetics                             9.0                   201.4
# topgifter                                  0.0                     0.0
# pica9                                      7.0                    21.4
# actionx                                    0.0                     0.0
# forgerock                                  9.0                   118.0
# nakivo                                  4800.0                    15.0
# cytogelpharma                              0.0                     0.0
# outboundengine                            32.5                    38.0
# datatorrent                                1.0                     7.0
# clicdata                                 100.0                   936.1
# celsion                                    2.7                    32.1
# worthit                                    6.8                     1.0
# nexb                                      37.0                     0.0
# qumulo                                  1900.0                     1.0
# soundbetter                                9.3                     0.0
# fitstar                                    0.0                     0.0
# gliffy                                     7.4                     7.8
# flowserve                               2300.0                    45.6
# codehs                                     5.6                     1.0
# snapshots                                  0.0                     0.0
# brookstone                                 5.5                     2.8
# simplyinsured                              2.0                     4.4
# emergefinancialwellness                    8.5                  4600.0
# yogatrail                                  1.0                     0.0
# cureeo                                   200.0                     0.0
# owncloud                                  10.7                     5.0
# pfsweb                                  8900.0                  4600.0
# hapyak                                     5.0                     9.4
# mark43                                   106.7                   670.4
# infocheckpoint                             5.0                     7.5
# ...                                        ...                     ...
# autolotto                                  0.0                     0.0
# icecreamlabs                              21.3                     0.0
# tenantturner                               2.6                    10.7
# monkey                                    57.9                   125.0
# logfuze                                 2200.0                    78.0
# yuggler                                   13.9                     0.0
# rpmarketplace                              4.5                    37.1
# sayist                                     3.8                    26.7
# casamatic                                486.9                     1.0
# atomized                                   8.2                     0.0
# planday                                    2.0                     0.0
# writelab                                   7.3                     0.0
# veryapt                                   18.0                     5.6
# zoomph                                    11.0                     7.0
# bbgventures                                0.0                     0.0
# doggybnb                                   1.0                     1.0
# sqoop                                      4.4                     1.0
# callr                                     11.0                    15.3
# wazala                                     0.0                     0.0
# hyperscience                               1.0                    21.0
# wevorce                                   11.1                    17.2
# revfluence                                18.1                     2.0
# sourcegraph                               30.0                    15.0
# moneylion                                  5.0                     1.6
# graybug                                    2.0                     0.0
# mongoosemetrics                            5.0                     0.0
# nventi                                     0.0                     0.0
# colonialbankfsb                           27.3                   786.0
# paracosm                                   1.1                     0.0
# extremeplasticsplus                        0.0                     0.0
#
# [624 rows x 10 columns]

# %%
tmp_revenue_list
# Out:
# [<div class="table-col revenue">$20M</div>,
#  <div class="table-col revenue">$30M</div>,
#  <div class="table-col revenue">$4.8M</div>,
#  <div class="table-col revenue">$152.1M</div>,
#  <div class="table-col revenue">$93.1M</div>,
#  <div class="table-col revenue">$21.4M</div>,
#  <div class="table-col revenue">$4.4M</div>,
#  <div class="table-col revenue">$2.8M</div>,
#  <div class="table-col revenue">$10M</div>,
#  <div class="table-col revenue">$8M</div>,
#  <div class="table-col revenue">$1.3M</div>]

# %%
competitors_revenue
# Out:
# ['20M',
#  '30M',
#  '4.8M',
#  '152.1M',
#  '93.1M',
#  '21.4M',
#  '4.4M',
#  '2.8M',
#  '10M',
#  '8M',
#  '1.3M']

# %%
competitors_revenue = []

# %%
for t in range(3,12):
    xpath_revenue = '//*[@id="__next"]/div/div/div[1]/div/div[2]/div[7]/div/div[2]/div['+str(t)+']/div[3]/div/div/div/div/ul/li[5]/div/div'

    if tree.xpath(xpath_revenue)==[]:
        break
    else:
        competitors_revenue = competitors_revenue.append(tree.xpath(xpath_revenue)[0].text)

# %%
tree.xpath('//*[@id="__next"]/div/div/div[1]/div/div[2]/div[7]/div/div[2]/div[4]/div[3]/div/div/div/div/ul/li[5]/div/div')
# Out:
# []

# %%
//*[@id="__next"]/div/div/div[1]/div/div[2]/div[7]/div/div[2]/div[3]/div[3]/div/div/div/div/ul/li[5]/div/div
//*[@id="__next"]/div/div/div[1]/div/div[2]/div[7]/div/div[2]/div[4]/div[3]/div/div/div/div/ul/li[5]/div/div

# %%
tree.xpath(xpath_revenue)
# Out:
# []

# %%
competitors_revenue
# Out:
# []

# %%
tmp_revenue_list = soup.find_all('div', attrs={'class': 'table-col revenue'})[1:]
competitors_revenue = []
for x in tmp_revenue_list:
    tmpvalue = re.findall(".*>(.*)<.*",str(x))[0]
    if len(tmpvalue)!=0:
        competitors_revenue.append(tmpvalue[1:])
competitors_revenue_float=[]
for i in competitors_revenue: 
    if i[:6] ==' &lt; ':
        competitors_revenue_float.append(convert_string_to_money(i[6:]))
    else:
        competitors_revenue_float.append(convert_string_to_money(i))
competitors_revenue_sum = np.array(competitors_revenue_float[1:]).sum()/10e6 #skip the searched company
try:
    annual_rev = competitors_revenue_float[0]/10e6
except:
    annual_rev = np.nan

competitor_count = len(competitors_revenue_float[1:])

HHI = (np.array(competitors_revenue_float[1:])**2).sum()/((np.array(competitors_revenue_float[1:]).sum())**2)
print (name,annual_rev, competitor_count, competitors_revenue_sum, HHI)
loop.run_until_complete(c.close_tab(tab))

# %%
def crawl_owler_company_info(name):
    c = Chrome(host=HOST, port=PORT)
    tab = c.tabs[0]
    tab = loop.run_until_complete(c.create_tab())
    loop.run_until_complete(tab.enable_page_events())
    company_url = 'https://www.owler.com/company/'+name
    print (company_url)
    result = sync_cmd(page.Page.navigate(url=company_url), 
                      await_on_event_type=page.FrameStoppedLoadingEvent)
    result = sync_cmd(dom.DOM.getDocument())
    result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
    page_source = result['ack']['result']['outerHTML']
    soup = BeautifulSoup(page_source, 'html.parser')

    tmp_revenue_list = soup.find_all('div', attrs={'class': 'table-col revenue'})[1:]
    competitors_revenue = []
    for x in tmp_revenue_list:
        tmpvalue = re.findall(".*>(.*)<.*",str(x))[0]
        if len(tmpvalue)!=0:
            competitors_revenue.append(tmpvalue[1:])
    competitors_revenue_float=[]
    for i in competitors_revenue: 
        if i[:6] ==' &lt; ':
            competitors_revenue_float.append(convert_string_to_money(i[6:]))
        else:
            competitors_revenue_float.append(convert_string_to_money(i))
    competitors_revenue_sum = np.array(competitors_revenue_float[1:]).sum()/10e6 #skip the searched company
    try:
        annual_rev = competitors_revenue_float[0]/10e6
    except:
        annual_rev = np.nan

    competitor_count = len(competitors_revenue_float[1:])

    HHI = (np.array(competitors_revenue_float[1:])**2).sum()/((np.array(competitors_revenue_float[1:]).sum())**2)
    print (name,annual_rev, competitor_count, competitors_revenue_sum, HHI)
    loop.run_until_complete(c.close_tab(tab))
    return annual_rev, competitor_count, competitors_revenue_sum, HHI

# %%
company_info_df = pd.read_excel('company_name.xlsx',index_col=0)

# %%
info_df =  pd.DataFrame(index=company_info_df.index ,columns=np.concatenate((np.array(['Company Business', 'Category', 'Company Revenue',
       'Competitor count (cap at 10)', 'Competitor Revenue in Total', 'HHI',
       'crawl_tried', 'potential crawl failing point', 'notes',
                  ]),np.array(['competitors revenue '+str(x+1) for x in range(10)]))))
info_df['crawl_tried'] =0
info_df['potential crawl failing point']=0
info_df['notes']=''
info_df.iloc[:,9:19] = 0

# %%
#info_df = pd.read_csv('tmp_company_info.csv',index_col=0)
for i in tqdm(range(info_df.shape[0])):
    if (info_df.iloc[i]['crawl_tried'] ==0) or (info_df.iloc[i]['potential crawl failing point'] ==1):
        try:
            info_df.iloc[i]['crawl_tried'] =1   
            #info_df.iloc[i,2:6] = crawl_owler_company_info(info_df.index[i])
            
            name=info_df.index[i]
            tab = c.tabs[0]
            tab = loop.run_until_complete(c.create_tab())
            loop.run_until_complete(tab.enable_page_events())
            result = sync_cmd(page.Page.navigate(url='https://www.owler.com/company/'+name), 
                              await_on_event_type=page.FrameStoppedLoadingEvent)
            result = sync_cmd(dom.DOM.getDocument())
            result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
            page_source = result['ack']['result']['outerHTML']
            soup = BeautifulSoup(page_source, 'html.parser')
            
            
            tmp_revenue_list = soup.find_all('div', attrs={'class': 'table-col revenue'})[1:]
            competitors_revenue = []
            for x in tmp_revenue_list:
                tmpvalue = re.findall(".*>(.*)<.*",str(x))[0]
                if len(tmpvalue)!=0:
                    competitors_revenue.append(tmpvalue[1:])
            competitors_revenue_float=[]
            for ixx in competitors_revenue: 
                if ixx[:6] ==' &lt; ':
                    competitors_revenue_float.append(convert_string_to_money(ixx[6:]))
                else:
                    competitors_revenue_float.append(convert_string_to_money(ixx))
            competitors_revenue_sum = np.array(competitors_revenue_float[1:]).sum()/10e6 #skip the searched company
            try:
                annual_rev = competitors_revenue_float[0]/10e6
            except:
                annual_rev = np.nan

            competitor_count = len(competitors_revenue_float[1:])

            HHI = (np.array(competitors_revenue_float[1:])**2).sum()/((np.array(competitors_revenue_float[1:]).sum())**2)
            print (name,annual_rev, competitor_count, competitors_revenue_sum, HHI)
            info_df.iloc[i,2:6] = annual_rev, competitor_count, competitors_revenue_sum, HHI
            info_df.iloc[i,9:competitor_count+9] = competitors_revenue_float[1:]
            loop.run_until_complete(c.close_tab(tab))
            
            
        except:
            info_df.iloc[i]['notes']='connectionclosed'
            #loop.run_until_complete(c.close_tab(tab))
        info_df.iloc[i]['crawl_tried'] =1
        if i>10:
            if info_df.iloc[i-10:i]['Competitor Revenue in Total'].sum()==0:
                print('the crwaler may have failed')
                info_df.iloc[i-10:i]['potential crawl failing point']=1
        if info_df.iloc[i]['Competitor Revenue in Total']!=0:
            info_df.iloc[i]['potential crawl failing point']=0
        info_df.to_csv('/home/chenxupeng/projects/crwal_company_info/tmp_company_info.csv')
        time.sleep(10)
# Out:
# HBox(children=(IntProgress(value=0, max=1414), HTML(value='')))
# /home/shibinbin/apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/shibinbin/apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in double_scalars
# buildingrobotics nan 0 0.0 nan
# medicalsimulation nan 0 0.0 nan
# cancergenetics 24.2 10 635.1 0.42384963125104835
# /home/shibinbin/apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# kindredbiosciences nan 0 0.0 nan
# topgifter 2.6 6 82.5 0.3078579013284986
# itnenergysystems nan 0 0.0 nan
# pica9 7.0 10 214.8 0.17687077042413046
# livelyformerlyhamlet nan 0 0.0 nan
# actionx 1.0 8 3477.9 0.47896876860716786
# forgerock 73.8 10 388.3 0.15601381516154553
# nakivo 19.0 10 6798.4 0.5231535939348865
# bobler nan 0 0.0 nan
# smartenergyinstruments nan 0 0.0 nan
# cytogelpharma 43.5 4 719.3 0.8318307939534444
# invine nan 0 0.0 nan
# shake nan 0 0.0 nan
# firstfunder nan 0 0.0 nan
# regulatorybinder nan 0 0.0 nan
# stroho nan 0 0.0 nan
# outboundengine 31.2 10 499.9 0.15895498806826927
# fidelissecuritysystems nan 0 0.0 nan
# capzure 1.0 1 3.9 0.6751353602665556
# /home/shibinbin/apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# trusper nan 0 0.0 nan
# birdhouseforautism nan 0 0.0 nan
# tixalert nan 0 0.0 nan
# 8bitfit nan 0 0.0 nan
# quantason nan 0 0.0 nan
# loopport nan 0 0.0 nan
# utahstreetlabs nan 0 0.0 nan
# bitscopic nan 0 0.0 nan
# datatorrent 2.8 10 78.3 0.17042332539176946
# investmentunderground nan 0 0.0 nan
# clicdata 1.0 10 3091.8 0.2927611029030194
# wwire nan 0 0.0 nan
# eccentexcorporation 1.0 0 0.0 1.0
# stationx nan 0 0.0 nan
# gamificationorg nan 0 0.0 nan
# celsion 1.0 10 432.7 0.19634958142847397
# beamzinteractive nan 0 0.0 nan
# nobleapplications nan 0 0.0 nan
# fingo nan 0 0.0 nan
# worthit 1.0 10 136.5 0.1593383140495868
# nexb 4.0 9 139.9 0.1699557786877131
# keenjar nan 0 0.0 nan
# qumulo 22.8 10 11231.9 0.6967411273068705
# soundbetter 7.0 9 66.1 0.2011655042190579
# maxmytv nan 0 0.0 nan
# fitstar 4.0 8 68.5 0.4039476813317479
# infernoredtechnology nan 0 0.0 nan
# mytraining nan 0 0.0 nan
# isitechnology nan 0 0.0 nan
# gliffy 5.2 10 102.4 0.2105778665303133
# flowserve 3800.0 10 103681.6 0.805550867721398
# king2 nan 0 0.0 nan
# pathfinderhealth nan 0 0.0 nan
# rethinkeducation nan 0 0.0 nan
# bionanovations nan 0 0.0 nan
# snapmyad nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/maxwellhealth"}, "id": 2}
# menloparksoftware nan 0 0.0 nan
# filmfunder nan 0 0.0 nan
# dfmsim nan 0 0.0 nan
# logicalchoicetechnologies nan 0 0.0 nan
# codehs 25.8 10 248.7 0.4114668498113809
# the crwaler may have failed
# /home/shibinbin/apps/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# snapshots 1.0 8 783.4 0.5222853093247963
# vendorsi nan 0 0.0 nan
# democrasoft nan 0 0.0 nan
# collectit nan 0 0.0 nan
# insidesalescom nan 0 0.0 nan
# brookstone 117.7 10 878.8 0.1860531428489427
# simplyinsured 1.0 10 275.0 0.3889547889098929
# pheebo nan 0 0.0 nan
# emergefinancialwellness 10.0 10 7007.0 0.4855963678997863
# yogatrail 8.0 9 78.0 0.20524878312601405
# yrmrkt nan 0 0.0 nan
# cureeo 12.5 9 273.9 0.5045154548079024
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/insightly"}, "id": 2}
# ocztechnology nan 0 0.0 nan
# nuvustudio nan 0 0.0 nan
# coub nan 0 0.0 nan
# positrondynamics nan 0 0.0 nan
# formzapper nan 0 0.0 nan
# repairreport nan 0 0.0 nan
# owncloud 4.4 10 175.3 0.23690476522269077
# lassomedia nan 0 0.0 nan
# pfsweb 325.8 10 234553.7 0.23543083248697785
# hapyak 1.0 10 78.3 0.23668798073941438
# mark43 5.6 10 1818.8 0.40230019669061556
# smartcoffeetechnology nan 0 0.0 nan
# infocheckpoint 1.0 10 356.1 0.22562984231308542
# wondermall nan 0 0.0 nan
# sphynkxtherapeutics nan 0 0.0 nan
# rijuven 3.0 10 31.0 0.14911764705882352
# brushfireinteractive 4.1 9 384.4 0.39084138744370406
# seekretreat 12.0 4 28.2 0.4470805178089651
# absolutdata 25.0 10 78672.1 0.40464191620117096
# aayuja 1.7 10 125.2 0.16267843048856748
# haload nan 0 0.0 nan
# poppin 63.6 10 252951.0 0.3763498021531174
# appcurious nan 0 0.0 nan
# adbrain 1.0 7 9652.9 0.5719143699595218
# maventusmedia nan 0 0.0 nan
# everwise nan 0 0.0 nan
# deepforestmedia 4.4 10 461.2 0.4886944274689718
# mindplatetv nan 0 0.0 nan
# zergnet 2.9 10 184.3 0.38643481992840967
# sesamii nan 0 0.0 nan
# crowdsupply 3.2 10 214.4 0.20867180741782007
# albaorbital nan 0 0.0 nan
# celebcalls nan 0 0.0 nan
# ultralinqhealthcaresolutions 10.0 10 308.5 0.5483339535548551
# parametric nan 0 0.0 nan
# higherlearningtechnologies nan 0 0.0 nan
# ovascience 1.0 9 121.5 0.2261877551020408
# tapfunder nan 0 0.0 nan
# proletariat 3.9 8 11361.9 0.45140808249814657
# gigturn 1.0 1 1.0 0.5
# goodco 11.9 9 115.9 0.33174879567791027
# editorially nan 0 0.0 nan
# pivotdesk 6.0 10 1382.1 0.8779456599513641
# hukkster nan 0 0.0 nan
# rebelmouse 3.1 8 5011.3 0.9177551389713006
# transloc 2.5 9 87.3 0.20220385811578315
# evereq nan 0 0.0 nan
# truesocialmetrics 1.0 10 355.3 0.2377161377865515
# getmaid 1.0 7 88.3 0.2816568833869
# petcube 1.2 10 336.0 0.4261196455634216
# healthidprofile nan 0 0.0 nan
# reschedge 2.0 9 25.0 0.178079561042524
# pipefish nan 0 0.0 nan
# cloudamize 1.0 10 75.5 0.12202998846597463
# pixelle nan 0 0.0 nan
# galls 214.9 9 53.3 0.648276882200279
# advicewallet nan 0 0.0 nan
# massroots 1.0 8 97.8 0.350341752856136
# wearingdigital nan 0 0.0 nan
# mojio nan 0 0.0 nan
# spikes 15.0 10 1010.2 0.6416409104685986
# bookacoachcom nan 0 0.0 nan
# imperative 6.4 1 3.0 0.5654142145767316
# threatstack 1.5 10 1358.5 0.3427427660034602
# pathwright nan 0 0.0 nan
# openidfoundation nan 0 0.0 nan
# checkio nan 0 0.0 nan
# sparkpage nan 0 0.0 nan
# telylabs 1.2 9 55245.7 0.8489231501654554
# lovesurf nan 0 0.0 nan
# cleanify 1.0 2 349.9 0.9668580105986471
# heartflow 7.6 8 136.1 0.31146666124285644
# completeset 1.0 10 797279.5 0.5013274788582246
# topfloor 5.6 10 49.6 0.12437644402436462
# splicemachine 4.3 10 657.4 0.35592471605770687
# ishbowl nan 0 0.0 nan
# pymetrics 1.4 8 40.8 0.16132836189663305
# loopcommerce 1.0 9 235355.7 0.9793365732609903
# cloudfinity nan 0 0.0 nan
# smartthings 6.5 8 202.3 0.3212867544516375
# leanplum 27.5 10 300.4 0.17890787261455968
# enchanteddiamonds nan 0 0.0 nan
# picovico 1.0 9 30.8 0.12829793125271943
# linchpin nan 0 0.0 nan
# baqbeat nan 0 0.0 nan
# writerly nan 0 0.0 nan
# peer5 15.0 10 3136.5 0.740625913701911
# gamziomobile nan 0 0.0 nan
# blackjet 5.0 10 179.4 0.14204478616230867
# intubus 3.2 9 62.1 0.24495027074944478
# unleash 10.0 6 30.8 0.46294694348327564
# rolltech nan 0 0.0 nan
# wymsee 1.4 9 144.6 0.39552355038468756
# yasabe nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/frrole"}, "id": 2}
# tenfoot nan 0 0.0 nan
# momentme nan 0 0.0 nan
# instacart 80.0 9 163.4 0.35865670462747345
# eventslice 1.0 0 0.0 1.0
# newsle 1.0 10 1618.3 0.42640018925969675
# copypress 5.3 5 165.7 0.3766300742108683
# easypost 5.0 10 4941.4 0.5377810013364293
# socii nan 0 0.0 nan
# careporthealth 3.0 10 443.5 0.2048707315452148
# protagenictherapeutics nan 0 0.0 nan
# fundersclub 3.9 10 117.2 0.48157032868946303
# endurancelendingnetwork nan 0 0.0 nan
# hiptype nan 0 0.0 nan
# sonda41 nan 0 0.0 nan
# thinkful 4.5 10 34.7 0.18874947938359016
# syncbak 10.7 10 255.8 0.19359947058844235
# plutora 12.0 10 657.0 0.3871844955212809
# neighborly 3.0 10 48.9 0.1223525306187607
# elephantis nan 0 0.0 nan
# inkmobility nan 0 0.0 nan
# birdbox nan 0 0.0 nan
# babylist 19.2 2 18.4 0.42485287460389315
# dinamundo nan 0 0.0 nan
# tipsolutions nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/agsquared"}, "id": 2}
# crowdhall nan 0 0.0 nan
# meldium 3.2 7 134.4 0.36206331969983774
# storefront 18.2 6 25.8 0.24709710743801652
# olset nan 0 0.0 nan
# fit3d 4.3 8 39.0 0.3402386273328035
# picklify nan 0 0.0 nan
# senseplatform nan 0 0.0 nan
# tubularlabs 10.7 8 130.4 0.18403090830826538
# svayananotechnologies nan 0 0.0 nan
# quikkly nan 0 0.0 nan
# sefaira 11.9 10 116.1 0.179769287109375
# passportparking nan 0 0.0 nan
# streamonce nan 0 0.0 nan
# mobilerealtyappscom nan 0 0.0 nan
# cleantie nan 0 0.0 nan
# urbanremedy 25.0 6 374.5 0.44371816460187247
# procuredhealth 13.5 10 1541.4 0.4177103105755672
# tradesy 25.0 9 834.1 0.2568764015680667
# pathbrite 3.3 10 85.9 0.19757083391984556
# aciworldwide 1000.0 10 7713.5 0.5619290422303098
# ocoos 9.8 9 5422.6 0.3186760766075212
# measureful nan 0 0.0 nan
# zumper 55.0 10 353.8 0.4859669942287292
# curalate 3.9 10 43.2 0.1098940231967941
# alwaysprepped nan 0 0.0 nan
# tealet 3.6 1 75.0 0.9125925062642037
# aviiq nan 0 0.0 nan
# variable nan 0 0.0 nan
# liquidcoolsolutions 10.0 8 63.4 0.19820104091648166
# spreeify 1.0 8 57.7 0.24525421613668089
# displair nan 0 0.0 nan
# handybook 5.0 9 180.1 0.23254298273802385
# wakiebudist nan 0 0.0 nan
# newsup nan 0 0.0 nan
# appio 1.0 1 1.0 0.5
# mobileroadie 1.1 9 64.1 0.17260717377394708
# shotfarm nan 0 0.0 nan
# musicdealers 8.5 10 434.9 0.5432164097130286
# rocketlistings nan 0 0.0 nan
# virool 18.5 9 324.1 0.31036434068108
# thedailyhundred nan 0 0.0 nan
# fancred 3.0 7 62508.0 0.8017990303527891
# swingbyswing 8.0 9 7981.0 0.9778674661261687
# muzzley 3.8 8 1338.6 0.41424963259371433
# verbalizeit 1.7 9 63.7 0.20813343433493253
# stackify 1.0 10 766.7 0.38586999539791494
# realscout 5.0 10 398.6 0.49771825620947646
# tarponbiosystems nan 0 0.0 nan
# dropship 12.3 10 170.1 0.4027952110264697
# twice nan 0 0.0 nan
# vhx 3.6 10 995.7 0.7407516793828129
# jetaport 2.4 6 114.8 0.3346340667916924
# klaviyo 9.4 9 600.7 0.6575759182000012
# gleepost nan 0 0.0 nan
# endplay 4.3 10 101.3 0.12548962637741046
# americanreadingcompany nan 0 0.0 nan
# meteorentertainment nan 0 0.0 nan
# predilytics nan 0 0.0 nan
# toptal 15.0 8 1280.9 0.5843957187394857
# worcesterpolytechnicinstitute nan 0 0.0 nan
# skytree 8.0 10 153.7 0.2193427210654881
# circleup 4.1 10 37.7 0.10166891783613012
# kippt 1.0 10 624.5 0.6471634714610407
# consultadoctor 19.2 10 301.0 0.2228959024282528
# antssoftware nan 0 0.0 nan
# cloudone 12.0 10 6479.1 0.8556250203739505
# plyfe 1.0 10 598.5 0.29913176187273105
# thebaycitizen nan 0 0.0 nan
# davidcorporation nan 0 0.0 nan
# naughtydog 40.0 10 29299.5 0.17399753538792873
# genesismedia 7.1 9 137.8 0.17715318291427753
# anonymizer nan 0 0.0 nan
# anaplan 248.1 10 1335.9 0.5995566300632588
# gnshealthcare 15.0 10 566.0 0.33233637772136
# veruta nan 0 0.0 nan
# thuuz 5.8 10 69.9 0.15348600206963103
# hartventures nan 0 0.0 nan
# commuteradvertising nan 0 0.0 nan
# figure8surgical nan 0 0.0 nan
# monetsoftware 12.5 10 442.3 0.31037979329640486
# transoniccombustion nan 0 0.0 nan
# polarispartners 78.5 8 26639.4 0.4730242596746263
# edenparkillumination nan 0 0.0 nan
# telenav 106.2 9 4633.7 0.5231358817846398
# thanx 1.7 10 54.6 0.18742211383447593
# theapphouse nan 0 0.0 nan
# nextstepliving 25.0 10 83.0 0.15185699588477367
# techranchaustin nan 0 0.0 nan
# polsense nan 0 0.0 nan
# spool nan 0 0.0 nan
# booktrack 3.3 10 275.5 0.28276879390871723
# giggle 5.0 9 59.4 0.15607036765556884
# esosolutions 14.1 10 1283.6 0.6114421654558406
# pramata 9.3 10 488.1 0.30817929146317585
# gazillionentertainment nan 0 0.0 nan
# gravityventures nan 0 0.0 nan
# fabricly nan 0 0.0 nan
# winstonpharmaceuticals nan 0 0.0 nan
# spotdock nan 0 0.0 nan
# truckingoffice nan 0 0.0 nan
# surgeaccelerator 5.7 10 97.7 0.15271859298362447
# azimadli 16.9 9 36248.2 0.990918619070568
# fobo 4.4 8 72.2 0.39598402061504273
# catalystsecure 23.8 9 602.9 0.2770435883998206
# netelement 62.8 10 17513.4 0.7855012247764558
# eroi nan 0 0.0 nan
# resumesponge nan 0 0.0 nan
# nanolumens 28.9 10 388710.0 0.41481582092055486
# videoreadr nan 0 0.0 nan
# kuehnleagrosystems nan 0 0.0 nan
# tetrisonline 8.0 6 65.5 0.34463232912212505
# omidyartechnologyventures nan 0 0.0 nan
# collagecom nan 0 0.0 nan
# legalsifter 2.2 9 40.4 0.1954087592849743
# clevelexecuitvesreachtheunreachable nan 0 0.0 nan
# bisresearch 9.5 9 169.0 0.17449897606101264
# papumba nan 0 0.0 nan
# jdlab nan 0 0.0 nan
# investfeedcom nan 0 0.0 nan
# opentest nan 0 0.0 nan
# creditera 4.0 10 1298.7 0.4249480572584074
# potentialabs nan 0 0.0 nan
# onpatient nan 0 0.0 nan
# fitnet 3.1 8 290.6 0.6207475357261312
# augurysystems nan 0 0.0 nan
# agilebio 4.5 1 1.0 0.7024793388429752
# tellspec 9.5 9 56.0 0.2545422760911369
# enlabdevelopmentstudio nan 0 0.0 nan
# chefsforseniors nan 0 0.0 nan
# silktours nan 0 0.0 nan
# petglad nan 0 0.0 nan
# evolvtechnologies nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/webee"}, "id": 2}
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/klhe"}, "id": 2}
# tvamediagroup nan 0 0.0 nan
# vroomcom nan 0 0.0 nan
# castifi nan 0 0.0 nan
# sparkfinance nan 0 0.0 nan
# the crwaler may have failed
# savalabs nan 0 0.0 nan
# the crwaler may have failed
# itmmobile nan 0 0.0 nan
# the crwaler may have failed
# saviantconsulting 3.5 10 277.0 0.546116846349624
# the crwaler may have failed
# turbotenant 2.0 10 1161.7 0.5375204782693139
# bizmo nan 0 0.0 nan
# girnarsoft 5.0 9 458.9 0.6056017008296484
# traknprotect 1.4 10 827.8 0.2526284931872798
# gandainnovativesolutions nan 0 0.0 nan
# loanly nan 0 0.0 nan
# rentlogic nan 0 0.0 nan
# edifa nan 0 0.0 nan
# socialix 2.0 8 35.3 0.20079925824235062
# edusontv nan 0 0.0 nan
# cinescout nan 0 0.0 nan
# tiinkk 1.0 9 513.1 0.6957952251090347
# resectechnologies 11.4 10 1546.9 0.31768927341559666
# june nan 0 0.0 nan
# beatgasm nan 0 0.0 nan
# blockstack 1.0 9 50.7 0.18372997018208756
# outerplaces 5.8 9 49.6 0.21940856781660129
# votifysocialvotingapp nan 0 0.0 nan
# showoffcom nan 0 0.0 nan
# mysalespeep nan 0 0.0 nan
# designerthemescom nan 0 0.0 nan
# buhz nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/dormillo"}, "id": 2}
# hopin nan 0 0.0 nan
# kairoswatches 1.0 6 187.2 0.8784293508274034
# ultradia nan 0 0.0 nan
# cooperatize nan 0 0.0 nan
# wishinguwell nan 0 0.0 nan
# lateralsv nan 0 0.0 nan
# rsvplaw nan 0 0.0 nan
# teamblind 1.1 10 2882.4 0.3393911923731254
# vibby nan 0 0.0 nan
# zipier nan 0 0.0 nan
# cellagain nan 0 0.0 nan
# jisto 1.0 10 93616.2 0.2601885011713582
# fashiongps 2.7 4 60.0 0.3860997280790784
# flashmit nan 0 0.0 nan
# foodcrave 4.0 10 99.6 0.2188100952579717
# teleretailcorporation nan 0 0.0 nan
# urbanbound 5.3 10 9053.7 0.4883652599318829
# gogig nan 0 0.0 nan
# waypointmedia 4.4 9 113.8 0.17697355424429043
# autolotto 1.5 4 17.5 0.2742382271468144
# flyspansystems nan 0 0.0 nan
# fusion3design nan 0 0.0 nan
# autopilot2 nan 0 0.0 nan
# linguistiko nan 0 0.0 nan
# creativwire nan 0 0.0 nan
# wardrobewakeup nan 0 0.0 nan
# bestimators nan 0 0.0 nan
# silverwing nan 0 0.0 nan
# moneylion 3.7 10 251.6 0.4440975487314832
# ontopic nan 0 0.0 nan
# zumaventures nan 0 0.0 nan
# avox2 nan 0 0.0 nan
# keanr nan 0 0.0 nan
# bentpixels nan 0 0.0 nan
# trinitypharmasolutions nan 0 0.0 nan
# advancedwearabledevices nan 0 0.0 nan
# parionsciences nan 0 0.0 nan
# ivincipartners nan 0 0.0 nan
# moneero nan 0 0.0 nan
# proteamedical nan 0 0.0 nan
# the crwaler may have failed
# lacoonsecurity nan 0 0.0 nan
# the crwaler may have failed
# airtouchcommunications nan 0 0.0 nan
# the crwaler may have failed
# solidinteractive nan 0 0.0 nan
# the crwaler may have failed
# graybug 28.6 9 38.6 0.2356283659297052
# the crwaler may have failed
# highperformancesystemscorporation nan 0 0.0 nan
# mongoosemetrics 1.0 9 197.3 0.3054538972084707
# nventi 5.7 7 105.1 0.2290138018219969
# supplychainconnect nan 0 0.0 nan
# ERROR:chromewhip.chrome.ChromeTab.send_handler:{"method": "Page.navigate", "params": {"url": "https://www.owler.com/company/bioconsortia"}, "id": 2}
# colonialbankfsb 17.9 10 913.8 0.7151744496888938
# livongohealth nan 0 0.0 nan
# paracosm 1.2 9 77.2 0.3343821584756351
# extremeplasticsplus 5.0 3 34.0 0.34911242603550297
# pronutria nan 0 0.0 nan

# %%
name='google'
tab = c.tabs[0]
tab = loop.run_until_complete(c.create_tab())
loop.run_until_complete(tab.enable_page_events())
result = sync_cmd(page.Page.navigate(url='https://www.crunchbase.com/organization/'+name), 
                  await_on_event_type=page.FrameStoppedLoadingEvent)
result = sync_cmd(dom.DOM.getDocument())
result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
page_source = result['ack']['result']['outerHTML']
tree = lxml.html.fromstring(page_source)
loop.run_until_complete(c.close_tab(tab))

# %%
xpath_revenue = '//*[@id="section-overview"]/mat-card/div[2]/image-with-fields-card/image-with-text-card/div/div/div[2]/div[2]/field-formatter/span/text()'

company_intro = tree.xpath(xpath_revenue)[0]
company_intro
# Out:
# 'Google is a multinational corporation that is specialized in internet-related services and products.'

# %%
company_categories = ''
for t in range(1,20):
    xpath_revenue = '//*[@id="section-overview"]/mat-card/div[2]/fields-card[1]/div/span[2]/field-formatter/identifier-multi-formatter/span/a['+str(t)+']'
    
    if tree.xpath(xpath_revenue)==[]:
        break
    else:
        company_categories = company_categories+', '+tree.xpath(xpath_revenue)[0].text[1:]
company_categories[2:]
# Out:
# 'Biotechnology, Health Care, Hospital'

# %%
crunch_info_df = pd.read_csv('whole_info_v3.csv',index_col=0)

# %%
info_df = crunch_info_df

# %%
info_df
# Out:
#                                   owler corrrectionn  \
# Company.name
# buildingrobotics                                 NaN
# medicalsimulation                      medsimulation
# cancergenetics                                   NaN
# kindredbiosciences                        kindredbio
# topgifter                                        NaN
# itnenergysystems                               itnes
# pica9                                            NaN
# livelyformerlyhamlet                             NaN
# actionx                                          NaN
# forgerock                                        NaN
# nakivo                                           NaN
# bobler                                           NaN
# smartenergyinstruments                se-instruments
# cytogelpharma                                    NaN
# invine                                           NaN
# shake                                            NaN
# firstfunder                                      NaN
# regulatorybinder                                 NaN
# stroho                                           NaN
# outboundengine                                   NaN
# fidelissecuritysystems                           NaN
# capzure                                          NaN
# trusper                                          NaN
# birdhouseforautism                               NaN
# tixalert                                         NaN
# 8bitfit                                          NaN
# quantason                                        NaN
# loopport                                         NaN
# utahstreetlabs                                   NaN
# bitscopic                                        NaN
# ...                                              ...
# inappad                                          NaN
# wardrobewakeup                                   NaN
# bestimators                                      NaN
# silverwing                             silverwingndt
# moneylion                                        NaN
# ontopic                                  ontopicshow
# zumaventures                                     NaN
# avox2                                            NaN
# keanr                                            NaN
# bentpixels                                       NaN
# trinitypharmasolutions                           NaN
# advancedwearabledevices                          NaN
# parionsciences                                parion
# ivincipartners                              visitpay
# moneero                                          NaN
# proteamedical                             protealife
# lacoonsecurity                                lacoon
# airtouchcommunications                           NaN
# solidinteractive                          thinksolid
# graybug                                          NaN
# highperformancesystemscorporation                NaN
# mongoosemetrics                                  NaN
# nventi                                           NaN
# supplychainconnect                               NaN
# bioconsortia                                     NaN
# colonialbankfsb                                  NaN
# livongohealth                                livongo
# paracosm                                         NaN
# extremeplasticsplus                              NaN
# pronutria                                        NaN
#
#                                                                     Company Business  \
# Company.name
# buildingrobotics                   Comfy is changing the way people interact with...
# medicalsimulation                  Medical Simulation provides full-service simul...
# cancergenetics                                                                   NaN
# kindredbiosciences                                                               NaN
# topgifter                                        Search and get Gift Recommendations
# itnenergysystems                   ITN Energy Systems is a research and product d...
# pica9                              The leading SaaS Brand Management Platform emp...
# livelyformerlyhamlet               Lively is the connected home health platform t...
# actionx                            ActionX_connects gaps between mobile customer ...
# forgerock                          ForgeRock digital identity management solution...
# nakivo                             NAKIVO Inc. provides fast, reliable and cost-e...
# bobler                             Bobler is a social media app (iPhone&Android) ...
# smartenergyinstruments             Smart Energy Instruments offers measurement te...
# cytogelpharma                      Cytogel Pharma is a bio-pharmaceutical develop...
# invine                                         Next-generation Menus For Restaurants
# shake                              Shake is a mobile application used to create, ...
# firstfunder                        First Funder is an uncommon approach to crowd ...
# regulatorybinder                                                                 NaN
# stroho                             Stroho helps homeowners purchase 'Unseen Essen...
# outboundengine                     OutboundEngine is super simple marketing softw...
# fidelissecuritysystems                                                           NaN
# capzure                            Knowledge Management + Ticketing + Time Tracki...
# trusper                            An app & web for healthy living inspiration by...
# birdhouseforautism                 Birdhouse is a social enterprise that provides...
# tixalert                                            Parking Ticket Buster Mobile App
# 8bitfit                            8BitFit helps people reach fitness goals with ...
# quantason                          Quantason develops bi-modal US/IDUS_ platform ...
# loopport                           Loopport creates and distributes loops, beats,...
# utahstreetlabs                     Utah Street Labs owns and operates copious.com...
# bitscopic                          Healthcare Data Analytics and AI; Clinical and...
# ...                                                                              ...
# inappad                            Leveraging AI and Big Data to Nudge Swing Vote...
# wardrobewakeup                                Designer Clothing Subscription Service
# bestimators                         The marketplace for big ticket home improvements
# silverwing                              Charter a private jet in minutes, not hours.
# moneylion                          MoneyLion is empowering the American dream by ...
# ontopic                            Use natural language to designate the complex ...
# zumaventures                       Zuma Ventures creates companies from idea to l...
# avox2                              Free or Freemium calls and data to anywhere RE...
# keanr                              Revolutionary tool to upgrade your social life...
# bentpixels                         Bent Pixels is a digital media company known f...
# trinitypharmasolutions             SHYFT helps life science companies integrate c...
# advancedwearabledevices            Weloop helps you broadcast live videos you are...
# parionsciences                     Parion Sciences is a development stage company...
# ivincipartners                     iVinci Health equips healthcare distributors w...
# moneero                            Moneero is The Social Wallet. Payments are not...
# proteamedical                      Protea Medical Center focuses on the treatment...
# lacoonsecurity                     Lacoon Mobile Security offers a solution that ...
# airtouchcommunications             AirTouch Communications, a technology firm, en...
# solidinteractive                                                                 NaN
# graybug                            GrayBug is a biotechnology company developing ...
# highperformancesystemscorporation  High Performance Systems is a company speciali...
# mongoosemetrics                    Mongoose Metrics is the authority for exposing...
# nventi                             Nventi helps organizations commercialize techn...
# supplychainconnect                 Supply Chain Connect helps companies optimize ...
# bioconsortia                       BioConsortia, based in Davis, California, is a...
# colonialbankfsb                    Colonial Bank FSB began in 1913 as a mortgage ...
# livongohealth                      Livongo is empowering people with chronic cond...
# paracosm                           Paracosm develops mobile 3D scanning, progress...
# extremeplasticsplus                Extreme Plastics Plus is a family-owned compan...
# pronutria                          Pronutria Biosciences is developing new nutrit...
#
#                                                                             Category  \
# Company.name
# buildingrobotics                   Artificial Intelligence, Business Intelligence...
# medicalsimulation                               Biotechnology, Health Care, Hospital
# cancergenetics                                                                   NaN
# kindredbiosciences                                                               NaN
# topgifter                                                 E-Commerce, Gift, Shopping
# itnenergysystems                   Information Technology, Product Management, Pr...
# pica9                              Advertising, Brand Marketing, Digital Media, D...
# livelyformerlyhamlet               Elderly, Hardware, Internet of Things, mHealth...
# actionx                                                       Ad Retargeting, Mobile
# forgerock                          Cyber Security, Enterprise Software, Identity ...
# nakivo                                       Computer, Enterprise Software, Security
# bobler                                                   Audio, Mobile, Social Media
# smartenergyinstruments             Energy, Energy Efficiency, Information Technology
# cytogelpharma                                  Biopharma, Biotechnology, Health Care
# invine                             E-Commerce, Information Technology, Internet, ...
# shake                                     Legal, Mobile, Small and Medium Businesses
# firstfunder                          Crowdfunding, Crowdsourcing, Financial Services
# regulatorybinder                                                                 NaN
# stroho                                           Clean Energy, E-Commerce, GreenTech
# outboundengine                     Advertising, Email Marketing, Marketing Automa...
# fidelissecuritysystems                                                           NaN
# capzure                                          CRM, Knowledge Management, Software
# trusper                            Content, Content Creators, E-Commerce, Marketp...
# birdhouseforautism                       EdTech, Health Care, Information Technology
# tixalert                                         Apps, Internet, Mobile, Mobile Apps
# 8bitfit                            Apps, Fitness, Gamification, Health Care, iOS,...
# quantason                          Biotechnology, Enterprise Software, Health Car...
# loopport                                                  Music, Musical Instruments
# utahstreetlabs                                E-Commerce, Group Buying, Social Media
# bitscopic                          Analytics, Big Data, Biotechnology, Clinical T...
# ...                                                                              ...
# inappad                            Advertising, Advertising Platforms, Artificial...
# wardrobewakeup                     E-Commerce, Fashion, Lifestyle, Subscription S...
# bestimators                                            Construction, Home Renovation
# silverwing                            Aerospace, Brand Marketing, E-Commerce, Travel
# moneylion                          Artificial Intelligence, Consumer Lending, Cre...
# ontopic                                                Financial Services, Real Time
# zumaventures                               Internet, Product Design, Venture Capital
# avox2                              Android, iOS, macOS, Messaging, Mobile, Softwa...
# keanr                                                     E-Commerce, Events, Mobile
# bentpixels                         Brand Marketing, Digital Entertainment, Digita...
# trinitypharmasolutions                               Health Care, Life Science, SaaS
# advancedwearabledevices                                           Hardware, Software
# parionsciences                                                Biotechnology, Medical
# ivincipartners                           Health Care, Medical, Professional Services
# moneero                            Bitcoin, Finance, FinTech, Mobile, Mobile Paym...
# proteamedical                                         Health Care, Hospital, Medical
# lacoonsecurity                                    Cyber Security, Security, Software
# airtouchcommunications                                   Marketing, Mobile, Wireless
# solidinteractive                                                                 NaN
# graybug                                          Biotechnology, Health Care, Medical
# highperformancesystemscorporation  Building Maintenance, Building Material, Const...
# mongoosemetrics                          Analytics, Biometrics, Marketing Automation
# nventi                                         Big Data, Intellectual Property, SaaS
# supplychainconnect                                       Chemical, E-Commerce, Sales
# bioconsortia                                     Agriculture, Biotechnology, Farming
# colonialbankfsb                                 Banking, Finance, Financial Services
# livongohealth                      Health Care, Health Diagnostics, Information T...
# paracosm                           3D Technology, Augmented Reality, Real Estate,...
# extremeplasticsplus                    Advanced Materials, Fashion, Service Industry
# pronutria                                  Biotechnology, Life Science, Therapeutics
#
#                                    Company Revenue  \
# Company.name
# buildingrobotics                               NaN
# medicalsimulation                             10.7
# cancergenetics                                24.2
# kindredbiosciences                             NaN
# topgifter                                      2.6
# itnenergysystems                               NaN
# pica9                                          7.0
# livelyformerlyhamlet                           NaN
# actionx                                        1.0
# forgerock                                     73.8
# nakivo                                        19.0
# bobler                                         NaN
# smartenergyinstruments                         1.0
# cytogelpharma                                 43.5
# invine                                         NaN
# shake                                          NaN
# firstfunder                                    NaN
# regulatorybinder                               NaN
# stroho                                         NaN
# outboundengine                                31.2
# fidelissecuritysystems                         NaN
# capzure                                        1.0
# trusper                                        NaN
# birdhouseforautism                             NaN
# tixalert                                       NaN
# 8bitfit                                        NaN
# quantason                                      NaN
# loopport                                       NaN
# utahstreetlabs                                 NaN
# bitscopic                                      NaN
# ...                                            ...
# inappad                                        NaN
# wardrobewakeup                                 NaN
# bestimators                                    NaN
# silverwing                                     1.0
# moneylion                                      3.7
# ontopic                                        NaN
# zumaventures                                   NaN
# avox2                                          NaN
# keanr                                          NaN
# bentpixels                                     NaN
# trinitypharmasolutions                         NaN
# advancedwearabledevices                        NaN
# parionsciences                                 1.0
# ivincipartners                                 5.0
# moneero                                        NaN
# proteamedical                                  NaN
# lacoonsecurity                                 1.0
# airtouchcommunications                         NaN
# solidinteractive                               4.4
# graybug                                       28.6
# highperformancesystemscorporation              NaN
# mongoosemetrics                                1.0
# nventi                                         5.7
# supplychainconnect                             NaN
# bioconsortia                                   1.0
# colonialbankfsb                               17.9
# livongohealth                                 30.0
# paracosm                                       1.2
# extremeplasticsplus                            5.0
# pronutria                                      NaN
#
#                                    Competitor count (cap at 10)  \
# Company.name
# buildingrobotics                                              0
# medicalsimulation                                            10
# cancergenetics                                               10
# kindredbiosciences                                            0
# topgifter                                                     6
# itnenergysystems                                              0
# pica9                                                        10
# livelyformerlyhamlet                                          0
# actionx                                                       8
# forgerock                                                    10
# nakivo                                                       10
# bobler                                                        0
# smartenergyinstruments                                        1
# cytogelpharma                                                 4
# invine                                                        0
# shake                                                         0
# firstfunder                                                   0
# regulatorybinder                                              0
# stroho                                                        0
# outboundengine                                               10
# fidelissecuritysystems                                        0
# capzure                                                       1
# trusper                                                       0
# birdhouseforautism                                            0
# tixalert                                                      0
# 8bitfit                                                       0
# quantason                                                     0
# loopport                                                      0
# utahstreetlabs                                                0
# bitscopic                                                     0
# ...                                                         ...
# inappad                                                       0
# wardrobewakeup                                                0
# bestimators                                                   0
# silverwing                                                    8
# moneylion                                                    10
# ontopic                                                       0
# zumaventures                                                  0
# avox2                                                         0
# keanr                                                         0
# bentpixels                                                    0
# trinitypharmasolutions                                        0
# advancedwearabledevices                                       0
# parionsciences                                                8
# ivincipartners                                               10
# moneero                                                       0
# proteamedical                                                 0
# lacoonsecurity                                               10
# airtouchcommunications                                        0
# solidinteractive                                              8
# graybug                                                       9
# highperformancesystemscorporation                             0
# mongoosemetrics                                               9
# nventi                                                        7
# supplychainconnect                                            0
# bioconsortia                                                  8
# colonialbankfsb                                              10
# livongohealth                                                 9
# paracosm                                                      9
# extremeplasticsplus                                           3
# pronutria                                                     0
#
#                                    Competitor Revenue in Total       HHI  \
# Company.name
# buildingrobotics                                           0.0       NaN
# medicalsimulation                                      36076.2  0.257775
# cancergenetics                                           652.2  0.462750
# kindredbiosciences                                         0.0       NaN
# topgifter                                                 82.5  0.326575
# itnenergysystems                                           0.0       NaN
# pica9                                                    214.8  0.187524
# livelyformerlyhamlet                                       0.0       NaN
# actionx                                                 3477.9  0.479244
# forgerock                                                388.3  0.184831
# nakivo                                                  6798.4  0.526074
# bobler                                                     0.0       NaN
# smartenergyinstruments                                    12.0  0.857988
# cytogelpharma                                            719.3  0.931826
# invine                                                     0.0       NaN
# shake                                                      0.0       NaN
# firstfunder                                                0.0       NaN
# regulatorybinder                                           0.0       NaN
# stroho                                                     0.0       NaN
# outboundengine                                           499.9  0.175520
# fidelissecuritysystems                                     0.0       NaN
# capzure                                                    3.9  0.675135
# trusper                                                    0.0       NaN
# birdhouseforautism                                         0.0       NaN
# tixalert                                                   0.0       NaN
# 8bitfit                                                    0.0       NaN
# quantason                                                  0.0       NaN
# loopport                                                   0.0       NaN
# utahstreetlabs                                             0.0       NaN
# bitscopic                                                  0.0       NaN
# ...                                                        ...       ...
# inappad                                                    0.0       NaN
# wardrobewakeup                                             0.0       NaN
# bestimators                                                0.0       NaN
# silverwing                                              1144.8  0.469031
# moneylion                                                251.6  0.457039
# ontopic                                                    0.0       NaN
# zumaventures                                               0.0       NaN
# avox2                                                      0.0       NaN
# keanr                                                      0.0       NaN
# bentpixels                                                 0.0       NaN
# trinitypharmasolutions                                     0.0       NaN
# advancedwearabledevices                                    0.0       NaN
# parionsciences                                           354.4  0.329961
# ivincipartners                                           466.7  0.558596
# moneero                                                    0.0       NaN
# proteamedical                                              0.0       NaN
# lacoonsecurity                                           382.1  0.683121
# airtouchcommunications                                     0.0       NaN
# solidinteractive                                          79.6  0.330228
# graybug                                                   38.6  0.165172
# highperformancesystemscorporation                          0.0       NaN
# mongoosemetrics                                          197.3  0.308532
# nventi                                                   105.1  0.251587
# supplychainconnect                                         0.0       NaN
# bioconsortia                                           13436.7  0.994546
# colonialbankfsb                                          913.8  0.743084
# livongohealth                                             96.8  0.245516
# paracosm                                                  77.2  0.344617
# extremeplasticsplus                                       34.0  0.437716
# pronutria                                                  0.0       NaN
#
#                                    crawl_tried  potential crawl failing point  \
# Company.name
# buildingrobotics                             0                              0
# medicalsimulation                            0                              0
# cancergenetics                               0                              0
# kindredbiosciences                           0                              0
# topgifter                                    0                              0
# itnenergysystems                             0                              0
# pica9                                        0                              0
# livelyformerlyhamlet                         0                              0
# actionx                                      0                              0
# forgerock                                    0                              0
# nakivo                                       0                              0
# bobler                                       0                              0
# smartenergyinstruments                       0                              0
# cytogelpharma                                0                              0
# invine                                       0                              0
# shake                                        0                              0
# firstfunder                                  0                              0
# regulatorybinder                             0                              0
# stroho                                       0                              0
# outboundengine                               0                              0
# fidelissecuritysystems                       0                              0
# capzure                                      0                              0
# trusper                                      0                              0
# birdhouseforautism                           0                              0
# tixalert                                     0                              0
# 8bitfit                                      0                              0
# quantason                                    0                              0
# loopport                                     0                              0
# utahstreetlabs                               0                              0
# bitscopic                                    0                              0
# ...                                        ...                            ...
# inappad                                      0                              0
# wardrobewakeup                               0                              0
# bestimators                                  0                              0
# silverwing                                   0                              0
# moneylion                                    0                              0
# ontopic                                      0                              1
# zumaventures                                 0                              1
# avox2                                        0                              1
# keanr                                        0                              1
# bentpixels                                   0                              1
# trinitypharmasolutions                       0                              1
# advancedwearabledevices                      0                              1
# parionsciences                               0                              1
# ivincipartners                               0                              1
# moneero                                      0                              1
# proteamedical                                0                              1
# lacoonsecurity                               0                              1
# airtouchcommunications                       0                              1
# solidinteractive                             0                              1
# graybug                                      0                              0
# highperformancesystemscorporation            0                              0
# mongoosemetrics                              0                              0
# nventi                                       0                              0
# supplychainconnect                           0                              0
# bioconsortia                                 0                              0
# colonialbankfsb                              0                              0
# livongohealth                                0                              0
# paracosm                                     0                              0
# extremeplasticsplus                          0                              0
# pronutria                                    0                              0
#
#                                    notes  competitors revenue 1  \
# Company.name
# buildingrobotics                     NaN                    0.0
# medicalsimulation                    NaN                   10.0
# cancergenetics                       NaN                    3.8
# kindredbiosciences                   NaN                    0.0
# topgifter                            NaN                    3.3
# itnenergysystems                     NaN                    0.0
# pica9                                NaN                   31.1
# livelyformerlyhamlet                 NaN                    0.0
# actionx                              NaN                  300.0
# forgerock                            NaN                   66.3
# nakivo                               NaN                  999.2
# bobler                               NaN                    0.0
# smartenergyinstruments               NaN                   12.0
# cytogelpharma                        NaN                    4.4
# invine                               NaN                    0.0
# shake                                NaN                    0.0
# firstfunder                          NaN                    0.0
# regulatorybinder                     NaN                    0.0
# stroho                               NaN                    0.0
# outboundengine                       NaN                   27.0
# fidelissecuritysystems               NaN                    0.0
# capzure                              NaN                    3.9
# trusper                              NaN                    0.0
# birdhouseforautism                   NaN                    0.0
# tixalert                             NaN                    0.0
# 8bitfit                              NaN                    0.0
# quantason                            NaN                    0.0
# loopport                             NaN                    0.0
# utahstreetlabs                       NaN                    0.0
# bitscopic                            NaN                    0.0
# ...                                  ...                    ...
# inappad                              NaN                    0.0
# wardrobewakeup                       NaN                    0.0
# bestimators                          NaN                    0.0
# silverwing                           NaN                   18.2
# moneylion                            NaN                  165.7
# ontopic                              NaN                    0.0
# zumaventures                         NaN                    0.0
# avox2                                NaN                    0.0
# keanr                                NaN                    0.0
# bentpixels                           NaN                    0.0
# trinitypharmasolutions               NaN                    0.0
# advancedwearabledevices              NaN                    0.0
# parionsciences                       NaN                    5.0
# ivincipartners                       NaN                   40.0
# moneero                              NaN                    0.0
# proteamedical                        NaN                    0.0
# lacoonsecurity                       NaN                    8.5
# airtouchcommunications               NaN                    0.0
# solidinteractive                     NaN                    7.5
# graybug                              NaN                    2.0
# highperformancesystemscorporation    NaN                    0.0
# mongoosemetrics                      NaN                   11.0
# nventi                               NaN                    3.8
# supplychainconnect                   NaN                    0.0
# bioconsortia                         NaN                    6.0
# colonialbankfsb                      NaN                    5.0
# livongohealth                        NaN                   25.0
# paracosm                             NaN                    3.0
# extremeplasticsplus                  NaN                   20.0
# pronutria                            NaN                    0.0
#
#                                    competitors revenue 2  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                   16.3
# cancergenetics                                       1.0
# kindredbiosciences                                   0.0
# topgifter                                            3.6
# itnenergysystems                                     0.0
# pica9                                               70.3
# livelyformerlyhamlet                                 0.0
# actionx                                           2300.0
# forgerock                                           33.5
# nakivo                                              11.4
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                        3.0
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                     150.0
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                         749.2
# moneylion                                           17.0
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                      50.4
# ivincipartners                                       4.0
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                       3.5
# airtouchcommunications                               0.0
# solidinteractive                                     4.2
# graybug                                             10.0
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                     20.7
# nventi                                              18.8
# supplychainconnect                                   0.0
# bioconsortia                                         3.0
# colonialbankfsb                                     21.0
# livongohealth                                        5.0
# paracosm                                             4.0
# extremeplasticsplus                                  5.0
# pronutria                                            0.0
#
#                                    competitors revenue 3  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                 7100.0
# cancergenetics                                     394.1
# kindredbiosciences                                   0.0
# topgifter                                           37.6
# itnenergysystems                                     0.0
# pica9                                               35.0
# livelyformerlyhamlet                                 0.0
# actionx                                            234.2
# forgerock                                           11.0
# nakivo                                              94.1
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                      694.1
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                      65.9
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                         167.4
# moneylion                                           30.5
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                      17.5
# ivincipartners                                       8.0
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                       1.9
# airtouchcommunications                               0.0
# solidinteractive                                     1.4
# graybug                                              7.5
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                     13.1
# nventi                                               4.4
# supplychainconnect                                   0.0
# bioconsortia                                        10.0
# colonialbankfsb                                      1.6
# livongohealth                                       10.0
# paracosm                                             3.0
# extremeplasticsplus                                  9.0
# pronutria                                            0.0
#
#                                    competitors revenue 4  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                12200.0
# cancergenetics                                       3.7
# kindredbiosciences                                   0.0
# topgifter                                           25.7
# itnenergysystems                                     0.0
# pica9                                               10.0
# livelyformerlyhamlet                                 0.0
# actionx                                              1.4
# forgerock                                           20.0
# nakivo                                             440.6
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                       17.8
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                     109.7
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                          50.0
# moneylion                                            5.0
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                     189.9
# ivincipartners                                       4.0
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                      19.1
# airtouchcommunications                               0.0
# solidinteractive                                     2.4
# graybug                                              6.7
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                     15.3
# nventi                                               5.3
# supplychainconnect                                   0.0
# bioconsortia                                         5.0
# colonialbankfsb                                      4.3
# livongohealth                                        6.5
# paracosm                                             2.0
# extremeplasticsplus                                  0.0
# pronutria                                            0.0
#
#                                    competitors revenue 5  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                10300.0
# ...
# lacoonsecurity                                       2.7
# airtouchcommunications                               0.0
# solidinteractive                                     3.9
# graybug                                              3.0
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                      3.1
# nventi                                              39.7
# supplychainconnect                                   0.0
# bioconsortia                                         5.0
# colonialbankfsb                                     13.2
# livongohealth                                        7.3
# paracosm                                            41.0
# extremeplasticsplus                                  0.0
# pronutria                                            0.0
#
#                                    competitors revenue 7  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                    1.0
# cancergenetics                                       3.5
# kindredbiosciences                                   0.0
# topgifter                                            0.0
# itnenergysystems                                     0.0
# pica9                                                4.4
# livelyformerlyhamlet                                 0.0
# actionx                                              4.4
# forgerock                                            1.0
# nakivo                                              35.3
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                        0.0
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                      22.2
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                           4.0
# moneylion                                           10.0
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                      13.4
# ivincipartners                                      20.0
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                       4.0
# airtouchcommunications                               0.0
# solidinteractive                                     5.2
# graybug                                              5.0
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                     10.0
# nventi                                              27.5
# supplychainconnect                                   0.0
# bioconsortia                                         3.7
# colonialbankfsb                                     10.2
# livongohealth                                        1.0
# paracosm                                             1.0
# extremeplasticsplus                                  0.0
# pronutria                                            0.0
#
#                                    competitors revenue 8  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                   21.7
# cancergenetics                                       6.5
# kindredbiosciences                                   0.0
# topgifter                                            0.0
# itnenergysystems                                     0.0
# pica9                                               29.4
# livelyformerlyhamlet                                 0.0
# actionx                                             24.9
# forgerock                                            8.0
# nakivo                                              27.6
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                        0.0
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                      31.6
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                           1.0
# moneylion                                            5.0
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                      37.3
# ivincipartners                                       7.3
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                       8.5
# airtouchcommunications                               0.0
# solidinteractive                                    12.4
# graybug                                              1.4
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                     15.8
# nventi                                               0.0
# supplychainconnect                                   0.0
# bioconsortia                                     13400.0
# colonialbankfsb                                     31.8
# livongohealth                                       38.0
# paracosm                                             4.4
# extremeplasticsplus                                  0.0
# pronutria                                            0.0
#
#                                    competitors revenue 9  \
# Company.name
# buildingrobotics                                     0.0
# medicalsimulation                                   32.2
# cancergenetics                                       9.0
# kindredbiosciences                                   0.0
# topgifter                                            0.0
# itnenergysystems                                     0.0
# pica9                                                7.0
# livelyformerlyhamlet                                 0.0
# actionx                                              0.0
# forgerock                                            9.0
# nakivo                                            4800.0
# bobler                                               0.0
# smartenergyinstruments                               0.0
# cytogelpharma                                        0.0
# invine                                               0.0
# shake                                                0.0
# firstfunder                                          0.0
# regulatorybinder                                     0.0
# stroho                                               0.0
# outboundengine                                      32.5
# fidelissecuritysystems                               0.0
# capzure                                              0.0
# trusper                                              0.0
# birdhouseforautism                                   0.0
# tixalert                                             0.0
# 8bitfit                                              0.0
# quantason                                            0.0
# loopport                                             0.0
# utahstreetlabs                                       0.0
# bitscopic                                            0.0
# ...                                                  ...
# inappad                                              0.0
# wardrobewakeup                                       0.0
# bestimators                                          0.0
# silverwing                                           0.0
# moneylion                                            5.0
# ontopic                                              0.0
# zumaventures                                         0.0
# avox2                                                0.0
# keanr                                                0.0
# bentpixels                                           0.0
# trinitypharmasolutions                               0.0
# advancedwearabledevices                              0.0
# parionsciences                                       0.0
# ivincipartners                                      13.7
# moneero                                              0.0
# proteamedical                                        0.0
# lacoonsecurity                                     314.6
# airtouchcommunications                               0.0
# solidinteractive                                     0.0
# graybug                                              2.0
# highperformancesystemscorporation                    0.0
# mongoosemetrics                                      5.0
# nventi                                               0.0
# supplychainconnect                                   0.0
# bioconsortia                                         0.0
# colonialbankfsb                                     27.3
# livongohealth                                        1.0
# paracosm                                             1.1
# extremeplasticsplus                                  0.0
# pronutria                                            0.0
#
#                                    competitors revenue 10
# Company.name
# buildingrobotics                                      0.0
# medicalsimulation                                  5400.0
# cancergenetics                                      201.4
# kindredbiosciences                                    0.0
# topgifter                                             0.0
# itnenergysystems                                      0.0
# pica9                                                21.4
# livelyformerlyhamlet                                  0.0
# actionx                                               0.0
# forgerock                                           118.0
# nakivo                                               15.0
# bobler                                                0.0
# smartenergyinstruments                                0.0
# cytogelpharma                                         0.0
# invine                                                0.0
# shake                                                 0.0
# firstfunder                                           0.0
# regulatorybinder                                      0.0
# stroho                                                0.0
# outboundengine                                       38.0
# fidelissecuritysystems                                0.0
# capzure                                               0.0
# trusper                                               0.0
# birdhouseforautism                                    0.0
# tixalert                                              0.0
# 8bitfit                                               0.0
# quantason                                             0.0
# loopport                                              0.0
# utahstreetlabs                                        0.0
# bitscopic                                             0.0
# ...                                                   ...
# inappad                                               0.0
# wardrobewakeup                                        0.0
# bestimators                                           0.0
# silverwing                                            0.0
# moneylion                                             1.6
# ontopic                                               0.0
# zumaventures                                          0.0
# avox2                                                 0.0
# keanr                                                 0.0
# bentpixels                                            0.0
# trinitypharmasolutions                                0.0
# advancedwearabledevices                               0.0
# parionsciences                                        0.0
# ivincipartners                                       12.0
# moneero                                               0.0
# proteamedical                                         0.0
# lacoonsecurity                                       13.4
# airtouchcommunications                                0.0
# solidinteractive                                      0.0
# graybug                                               0.0
# highperformancesystemscorporation                     0.0
# mongoosemetrics                                       0.0
# nventi                                                0.0
# supplychainconnect                                    0.0
# bioconsortia                                          0.0
# colonialbankfsb                                     786.0
# livongohealth                                         0.0
# paracosm                                              0.0
# extremeplasticsplus                                   0.0
# pronutria                                             0.0
#
# [1414 rows x 20 columns]

# %%
info_df =  pd.DataFrame(index=crunch_info_df.index ,columns=['Company Business', 'Category'
       'crawl_tried', 'potential crawl failing point', 'notes'])
info_df['crawl_tried'] =0
info_df['notes']=''

# %%
#info_df = pd.read_csv('tmp_company_info.csv',index_col=0)
for i in tqdm(range(info_df.shape[0])):
    if info_df.iloc[i]['Company Business']!=info_df.iloc[i]['Company Business']:
        try:
            info_df.iloc[i]['crawl_tried'] =1   

            name=info_df.index[i]
            
            tab = c.tabs[0]
            tab = loop.run_until_complete(c.create_tab())
            loop.run_until_complete(tab.enable_page_events())
            result = sync_cmd(page.Page.navigate(url='https://www.crunchbase.com/organization/'+name), 
                              await_on_event_type=page.FrameStoppedLoadingEvent)
            result = sync_cmd(dom.DOM.getDocument())
            result = sync_cmd(dom.DOM.getOuterHTML(result['ack']['result']['root'].nodeId))
            page_source = result['ack']['result']['outerHTML']
            tree = lxml.html.fromstring(page_source)
            loop.run_until_complete(c.close_tab(tab))
            xpath_revenue = '//*[@id="section-overview"]/mat-card/div[2]/image-with-fields-card/image-with-text-card/div/div/div[2]/div[2]/field-formatter/span/text()'

            company_intro = tree.xpath(xpath_revenue)[0]
            company_categories = ''
            for t in range(1,20):
                xpath_revenue = '//*[@id="section-overview"]/mat-card/div[2]/fields-card[1]/div/span[2]/field-formatter/identifier-multi-formatter/span/a['+str(t)+']'

                if tree.xpath(xpath_revenue)==[]:
                    break
                else:
                    company_categories = company_categories+', '+tree.xpath(xpath_revenue)[0].text[1:]
            
            info_df.iloc[i,0] = company_intro
            info_df.iloc[i,1] = company_categories[2:]
            print (name,company_intro,company_categories[2:])
            
            loop.run_until_complete(c.close_tab(tab))
            
            
        except:
            info_df.iloc[i]['notes']='connectionclosed'
            #loop.run_until_complete(c.close_tab(tab))
        info_df.iloc[i]['crawl_tried'] =1
        
        info_df.to_csv('/home/chenxupeng/projects/crwal_company_info/whole_info_v4.csv')
        time.sleep(np.random.uniform(0.5,1))
# Out:
# HBox(children=(IntProgress(value=0, max=1414), HTML(value='')))
# flowserve Flowserve specializes in supplying pumps, valves, seals, automation, and services to the power, oil, gas, chemical, and other industries. Industrial Automation, Logistics
# democrasoft Democrasoft is a leading provider of innovation in social collaboration and voting platforms for building successful online communities. Collaboration, Knowledge Management, Software
# pfsweb PFSweb develops and deploys comprehensive end-to-end e-Commerce solutions for a wide range of industries. Consulting, E-Commerce, Information Services, Information Technology
# ovascience OvaScience is a life sciences company focused on the discovery, development and commercialization of treatments for infertility. Biotechnology, Health Care, Life Science
# hellofresh HelloFresh is a food subscription company that sends pre-portioned ingredients to users’ doorstep each week. Consumer, Cooking, Food and Beverage, Subscription Service
# transbiotec TransBiotec, a development-stage company, focuses on the development, marketing and sale of non-invasive alcohol sensing systems in the U.S. Manufacturing, Public Transportation
# exablox Exablox provides a scale-out, cloud-based storage and data management solution. Cloud Computing, Enterprise Software, Flash Storage, Hardware
# hanesbrands Based in Winston-Salem, N.C., Hanesbrands Inc. (NYSE:HBI) is a global consumer goods company with more than a century of history and a Consumer Goods, E-Commerce, Retail
# good44 Etsy for food, health and wellness E-Commerce, Organic Food, Personal Health
# rolltech Rolltech is a global competition platform with real-time scores, stats, and connection to your favorite bowlers. Mobile, Sports
# powerlinx Powerlinx offers a business platform that connects companies to new markets, growth opportunities, strategic partnerships, and one another. B2B, Business Development, Small and Medium Businesses
# studysoup StudySoup is an exchange where students can upload or download class notes. Content, Education, Publishing, Universities
# leadid Jornaya is a consumer journey insight platform that provides companies with the highest-resolution view of the consumer buying journey. Analytics, Big Data, Compliance, Consumer, Enterprise Software, Marketing
# clever Clever builds the platform for modern learning software after extracting student data from school legacy data systems. Big Data, Data Integration, EdTech, Education
# conocophillips ConocoPhillips has a time-honored tradition of placing safety, health and environmental stewardship at the top of their operating Energy, Oil and Gas
# lantronix Lantronix is a global provider of smart IoT (Internet of Things) solutions. Hardware, Internet of Things, IT Infrastructure, Network Security, Software
# tealet Online Farmer's Market for Tea on Bitcoin E-Commerce, Parenting, Subscription Service, Tea, Video
# nanoviricides NanoViricides is a nano-biopharmaceutical company that develops therapeutics for patients suffering from life-threatening viral infections. Biopharma, Biotechnology, Medical
# anaplan Anaplan provides a connected planning platform that helps businesses make better-informed plans and decisions faster. Enterprise Software, Information Technology, Sales
# telenav Telenav is a leading provider of connected car and location-based services, focused on transforming life on the go. Advertising, Advertising Platforms, Automotive, GPS, Local, Location Based Services, Mapping Services, Mobile, Mobile Advertising, Mobile Apps, Navigation, Search Engine, Wireless
